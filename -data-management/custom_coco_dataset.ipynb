# %% [markdown]
# # Custom Coco Dataset

# %% [markdown]
# # Resize Image Data

# %%
import json
from PIL import Image
import os

# %%
# Set the target size for resizing
# Raw images are 8/6 -> 8000x6000 pixels
target_size = (640, 640)
input_folder = "/Users/johannes/Code/Work/Exports/NanoStore_Full_COCO"
output_folder = "/Users/johannes/Code/labelstudio/NanoStore_Full_COCO_resized"
original_json_file = '/Users/johannes/Code/Work/Exports/NanoStore_Full_COCO/result.json'

# %%
def resize_images(input_folder, output_folder, target_size=(640, 640)):
    # Create the output folder if it doesn't exist
    output_images_folder = os.path.join(output_folder, "images")
    if not os.path.exists(output_images_folder):
        os.makedirs(output_images_folder)

    # List all files in the input folder
    files = os.listdir(input_folder)

    for file in files:
        if file.endswith(".png"):
            # Open the image
            image_path = os.path.join(input_folder, file)
            img = Image.open(image_path)

            # Resize the image
            resized_img = img.resize(target_size, Image.ANTIALIAS)

            # Save the resized image to the output folder
            output_path = os.path.join(output_images_folder, file)
            resized_img.save(output_path)

            print(f"Resized {file} to {target_size}")

# %%
# Resize images
resize_images(os.path.join(input_folder, 'images'), output_folder, target_size)
# Out:
# /var/folders/64/sth8xpv12c5858fnxytdg_200000gn/T/ipykernel_15046/2111692543.py:17: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   resized_img = img.resize(target_size, Image.ANTIALIAS)
# Resized 127d2e73-176_0_99.png to (640, 640)
# Resized 7739ad30-172_0_120.png to (640, 640)
# Resized 750e6d49-172_1_124.png to (640, 640)
# Resized 11d368c4-172_0_43.png to (640, 640)
# Resized 9d6d203d-173_0_3.png to (640, 640)
# Resized 304c9ad4-173_0_47.png to (640, 640)
# Resized 234b0062-176_0_367721.png to (640, 640)
# Resized c27c84b1-173_0_74.png to (640, 640)
# Resized 67d8c9e2-176_0_458981.png to (640, 640)
# Resized aa2ed50d-172_0_139.png to (640, 640)
# Resized 8f1d0f74-172_0_2.png to (640, 640)
# Resized 8cb19294-172_0_37.png to (640, 640)
# Resized 094f15f6-172_0_69.png to (640, 640)
# Resized e55c5933-173_0_52.png to (640, 640)
# Resized 242c0a4e-172_0_3.png to (640, 640)
# Resized 9b88abfa-176_1_62.png to (640, 640)
# Resized b2e5c6b1-172_0_31.png to (640, 640)
# Resized 8fdae462-173_0_44.png to (640, 640)
# Resized 2dab6b23-176_1_73.png to (640, 640)
# Resized 75e28be8-172_0_60.png to (640, 640)
# Resized 6f6c3b6f-176_0_51.png to (640, 640)
# Resized 486f751d-172_0_104.png to (640, 640)
# Resized dae5793c-172_0_25.png to (640, 640)
# Resized 478f3a04-173_0_120.png to (640, 640)
# Resized d61261f0-172_0_73.png to (640, 640)
# Resized e97bfea0-173_0_909886.png to (640, 640)
# Resized 4303ca20-176_1_18.png to (640, 640)
# Resized bf74b1ca-173_0_6.png to (640, 640)
# Resized 2077d2e9-172_0_109.png to (640, 640)
# Resized 1a427ee2-176_1_43.png to (640, 640)
# Resized 6fb26cda-176_0_147.png to (640, 640)
# Resized 79e9452f-173_1_100.png to (640, 640)
# Resized 9b618f3f-172_0_91.png to (640, 640)
# Resized b797544b-176_0_171.png to (640, 640)
# Resized 4d90b722-172_0_96.png to (640, 640)
# Resized b9224b4e-176_0_143.png to (640, 640)
# Resized 2d33d2b9-176_0_4.png to (640, 640)
# Resized 2bbffbc8-176_0_129.png to (640, 640)
# Resized abdf0846-176_0_34.png to (640, 640)
# Resized e11fb5c0-172_0_40.png to (640, 640)
# Resized 56e35fed-173_0_113.png to (640, 640)
# Resized a33ee8e9-172_0_147.png to (640, 640)
# Resized ce864c82-172_0_17.png to (640, 640)
# Resized a2ded496-176_0_156.png to (640, 640)
# Resized 6e855c9e-172_0_37.png to (640, 640)
# Resized 2389e401-172_0_122.png to (640, 640)
# Resized a00100de-172_0_145.png to (640, 640)
# Resized 5320fd2e-172_0_12.png to (640, 640)
# Resized 8ff13f76-173_0_128.png to (640, 640)
# Resized 22f69b60-172_0_121.png to (640, 640)
# Resized 04eada69-173_1_158.png to (640, 640)
# Resized b86937c4-173_0_25.png to (640, 640)
# Resized 48705cd7-173_0_18.png to (640, 640)
# Resized 4e90463a-172_0_90.png to (640, 640)
# Resized f0110e3d-173_1_120.png to (640, 640)
# Resized b7c74a04-173_0_119.png to (640, 640)
# Resized 5c204a8d-172_0_52.png to (640, 640)
# Resized da904107-172_1_107.png to (640, 640)
# Resized 9ec7e785-176_1_54.png to (640, 640)
# Resized 1d1e5944-176_0_72.png to (640, 640)
# Resized e5c06b89-173_0_27.png to (640, 640)
# Resized 8bcfa5f2-176_0_120.png to (640, 640)
# Resized d988af20-173_0_154.png to (640, 640)
# Resized 8ad1a522-172_0_16.png to (640, 640)
# Resized f37882e4-172_0_107.png to (640, 640)
# Resized 3f59e92f-172_0_56.png to (640, 640)
# Resized 8dc90855-172_0_8.png to (640, 640)
# Resized 6702cc5c-173_0_173.png to (640, 640)
# Resized 2654f718-173_1_167.png to (640, 640)
# Resized bd48ff33-173_0_123.png to (640, 640)
# Resized c2f5ce11-176_1_83.png to (640, 640)
# Resized 9e1569e4-176_0_111.png to (640, 640)
# Resized 887ece6b-172_0_125.png to (640, 640)
# Resized caad876c-173_0_30.png to (640, 640)
# Resized 1e7a955f-172_0_40.png to (640, 640)
# Resized df1bb384-173_0_49.png to (640, 640)
# Resized 57eece14-173_1_164.png to (640, 640)
# Resized 7e003bd2-172_0_93.png to (640, 640)
# Resized cf58cd4a-173_0_61.png to (640, 640)
# Resized 30416e8d-173_0_82.png to (640, 640)
# Resized 986efece-172_0_136.png to (640, 640)
# Resized 1020612e-172_0_111.png to (640, 640)
# Resized 7c40d80a-173_0_22.png to (640, 640)
# Resized 090dded1-173_0_102.png to (640, 640)
# Resized ae3f789a-176_1_59.png to (640, 640)
# Resized 7d207969-173_1_172.png to (640, 640)
# Resized 65d26ba6-173_0_81.png to (640, 640)
# Resized 95bd475e-173_0_69.png to (640, 640)
# Resized cc798cb1-173_0_2.png to (640, 640)
# Resized dd275a88-173_0_161.png to (640, 640)
# Resized f72826ee-172_0_53.png to (640, 640)
# Resized 0a717d38-176_1_38.png to (640, 640)
# Resized 6cf0c098-172_0_24.png to (640, 640)
# Resized 490c2b67-173_0_112.png to (640, 640)
# Resized 35ab1b48-172_1_127.png to (640, 640)
# Resized 8930576b-176_1_103.png to (640, 640)
# Resized b2b9b438-173_0_55.png to (640, 640)
# Resized 716b714b-173_0_66.png to (640, 640)
# Resized 95796a18-173_0_14.png to (640, 640)
# Resized 5155adca-172_0_100.png to (640, 640)
# Resized c756a3b9-172_0_46.png to (640, 640)
# Resized f49dd0d3-173_0_989690.png to (640, 640)
# Resized 5274920e-176_0_149.png to (640, 640)
# Resized 85ab91a1-173_0_79.png to (640, 640)
# Resized f39a45c8-173_1_103.png to (640, 640)
# Resized afc57eac-176_0_75.png to (640, 640)
# Resized 815fff43-172_1_121.png to (640, 640)
# Resized 5a68593e-172_0_165.png to (640, 640)
# Resized bf1c9791-172_0_60.png to (640, 640)
# Resized 3712e312-172_0_62.png to (640, 640)
# Resized 6f091929-176_0_90.png to (640, 640)
# Resized 769c5f10-172_0_939454.png to (640, 640)
# Resized c69584b0-173_0_141.png to (640, 640)
# Resized c0221b60-173_0_170.png to (640, 640)
# Resized 95224323-172_0_28.png to (640, 640)
# Resized 42d9b68d-173_0_110.png to (640, 640)
# Resized d935648c-176_0_54.png to (640, 640)
# Resized 4c65d20a-173_1_147.png to (640, 640)
# Resized 8f3f878c-172_0_156.png to (640, 640)
# Resized b5be25ef-172_0_72.png to (640, 640)
# Resized 47f4458f-173_0_13.png to (640, 640)
# Resized 4d5cb782-173_0_118.png to (640, 640)
# Resized 92660751-173_0_107.png to (640, 640)
# Resized 45bc3261-176_1_32.png to (640, 640)
# Resized 2607aeb9-176_1_1.png to (640, 640)
# Resized 5572f2fb-173_1_156.png to (640, 640)
# Resized a9972f35-173_1_101.png to (640, 640)
# Resized 3eb7194a-172_0_112.png to (640, 640)
# Resized d9f30a70-173_0_41.png to (640, 640)
# Resized 14362dde-173_0_105.png to (640, 640)
# Resized 4ce5be3f-173_0_41.png to (640, 640)
# Resized d4b6c8de-172_0_11.png to (640, 640)
# Resized 2f30dcdd-173_1_142.png to (640, 640)
# Resized bcfbd878-172_0_88425.png to (640, 640)
# Resized befaab9d-172_0_34.png to (640, 640)
# Resized 713dcbf3-173_0_55058.png to (640, 640)
# Resized 8909c7a1-173_0_98.png to (640, 640)
# Resized d964d8ac-172_0_87.png to (640, 640)
# Resized b41503f8-172_0_80.png to (640, 640)
# Resized e532d2f8-172_0_97.png to (640, 640)
# Resized a66aa47e-173_0_71.png to (640, 640)
# Resized c0117cd4-173_0_138.png to (640, 640)
# Resized 184aa59c-172_0_47.png to (640, 640)
# Resized b49cc48e-173_0_33.png to (640, 640)
# Resized c12bc924-173_0_143.png to (640, 640)
# Resized cdc1503e-172_0_135.png to (640, 640)
# Resized bfa01b60-173_0_139.png to (640, 640)
# Resized 7186335d-172_1_105.png to (640, 640)
# Resized b1e47dc9-176_1_65.png to (640, 640)
# Resized 7a17d4a0-173_0_20.png to (640, 640)
# Resized 477fdee5-176_0_232078.png to (640, 640)
# Resized 0cd336ed-173_0_115.png to (640, 640)
# Resized 89d4ec98-172_0_119.png to (640, 640)
# Resized fc134532-172_0_54.png to (640, 640)
# Resized 93bfd41d-172_0_90.png to (640, 640)
# Resized 76e59120-173_0_88.png to (640, 640)
# Resized 6a6b2929-172_0_128.png to (640, 640)
# Resized 9a0737df-172_0_43.png to (640, 640)
# Resized cac8c9be-173_0_542226.png to (640, 640)
# Resized 29423669-173_0_156.png to (640, 640)
# Resized 5e6a6e0e-172_0_141.png to (640, 640)
# Resized 6b058708-173_0_117.png to (640, 640)
# Resized f20c1c49-172_0_66.png to (640, 640)
# Resized 6dc93a63-173_0_17950.png to (640, 640)
# Resized 5ed924d2-173_0_77.png to (640, 640)
# Resized f7c710e8-172_0_107.png to (640, 640)
# Resized 7c0ca333-172_0_0.png to (640, 640)
# Resized dd76cc9f-173_0_93.png to (640, 640)
# Resized 31e9cd85-172_0_72.png to (640, 640)
# Resized 82bfb7e3-176_0_117.png to (640, 640)
# Resized 8400a426-176_0_28.png to (640, 640)
# Resized 16ec8550-172_0_77.png to (640, 640)
# Resized 444a0c69-173_0_30.png to (640, 640)
# Resized aa631778-176_1_92.png to (640, 640)
# Resized fd90daeb-176_1_7.png to (640, 640)
# Resized bb0dd191-172_1_142.png to (640, 640)
# Resized 9e356010-176_0_22.png to (640, 640)
# Resized afd5af4e-176_0_25.png to (640, 640)
# Resized 74a6c813-173_0_93.png to (640, 640)
# Resized 7a5689e4-173_0_149.png to (640, 640)
# Resized 4984580a-176_0_137.png to (640, 640)
# Resized 4b38713d-172_0_59.png to (640, 640)
# Resized f2088252-173_1_130.png to (640, 640)
# Resized c42f787c-172_1_135.png to (640, 640)
# Resized 1a0324f1-172_0_75.png to (640, 640)
# Resized 98853d71-172_0_141.png to (640, 640)
# Resized 4ca1272b-173_0_57.png to (640, 640)
# Resized 374d8839-172_0_159.png to (640, 640)
# Resized 06e2e3d1-173_0_33.png to (640, 640)
# Resized e63d74a5-172_0_82.png to (640, 640)
# Resized 1b7a457e-173_0_433626.png to (640, 640)
# Resized 04457b74-173_1_102.png to (640, 640)
# Resized 37270a44-176_0_42.png to (640, 640)
# Resized 509e19aa-176_0_87.png to (640, 640)
# Resized 628aa78b-172_0_133.png to (640, 640)
# Resized 9734894d-172_0_16.png to (640, 640)
# Resized 7353adcb-173_0_132.png to (640, 640)
# Resized 672dc2af-173_1_136.png to (640, 640)
# Resized 82110a59-173_0_8.png to (640, 640)
# Resized 968a6cfe-172_1_148.png to (640, 640)
# Resized a958016c-173_0_129.png to (640, 640)
# Resized 2a431ee3-173_0_95.png to (640, 640)
# Resized f06e540f-173_0_96.png to (640, 640)
# Resized 66ba5578-173_1_112.png to (640, 640)
# Resized 35e0e089-172_0_56.png to (640, 640)
# Resized 5cd55f7e-172_0_25.png to (640, 640)
# Resized 59025f79-172_0_22.png to (640, 640)
# Resized 33f99390-176_1_10.png to (640, 640)
# Resized 161057c9-173_0_139.png to (640, 640)
# Resized c7dfc66a-173_0_49.png to (640, 640)
# Resized 970ff039-173_1_117.png to (640, 640)
# Resized 89c96a35-172_0_129.png to (640, 640)
# Resized 2b2dbd01-173_1_144.png to (640, 640)
# Resized 55ef2119-173_0_156.png to (640, 640)
# Resized 8b36a22f-173_0_90.png to (640, 640)
# Resized 09a75303-173_0_120.png to (640, 640)
# Resized 8e701dd2-173_0_150.png to (640, 640)
# Resized 35d4b5cf-176_1_88.png to (640, 640)
# Resized c4cf8d1e-172_1_100.png to (640, 640)
# Resized 5f6ba6e3-176_0_66.png to (640, 640)
# Resized 9c7d7e59-173_0_126.png to (640, 640)
# Resized ce2bc92d-173_1_108.png to (640, 640)
# Resized 23493c49-176_0_43.png to (640, 640)
# Resized 00e29a55-172_0_113.png to (640, 640)
# Resized 9e9358b1-173_0_131.png to (640, 640)
# Resized cec25b5d-173_0_128.png to (640, 640)
# Resized 1884c233-173_0_66.png to (640, 640)
# Resized 6745cb38-176_0_161.png to (640, 640)
# Resized 96cfa92c-173_0_137.png to (640, 640)
# Resized 51f9de16-176_1_21.png to (640, 640)
# Resized 8310c91e-172_0_115.png to (640, 640)
# Resized 3aa2c907-173_0_58.png to (640, 640)
# Resized e5ff5581-172_0_117.png to (640, 640)
# Resized bc89800f-173_0_105.png to (640, 640)
# Resized 6a0aae43-173_0_11.png to (640, 640)
# Resized 5c842df3-172_0_5.png to (640, 640)
# Resized 84cd7fa3-172_0_34.png to (640, 640)
# Resized eb8c48f3-176_1_76.png to (640, 640)
# Resized 66bf05af-176_1_35.png to (640, 640)
# Resized 1c942ad5-172_1_102.png to (640, 640)
# Resized f54477b4-172_0_19.png to (640, 640)
# Resized f2d915fd-173_1_139.png to (640, 640)
# Resized 4746a4a1-173_0_102.png to (640, 640)
# Resized bde7e0bc-173_0_27.png to (640, 640)
# Resized 554f010b-173_0_9.png to (640, 640)
# Resized caffa2bc-176_1_81.png to (640, 640)
# Resized a840d1f8-172_1_145.png to (640, 640)
# Resized abbd33b9-176_0_382183.png to (640, 640)
# Resized 01350713-172_0_125.png to (640, 640)
# Resized 018dd9ea-173_0_861239.png to (640, 640)
# Resized 979a9d1e-173_0_141.png to (640, 640)
# Resized ad3ab2d9-176_1_57.png to (640, 640)
# Resized 3f363be6-176_0_108.png to (640, 640)
# Resized 8e257980-172_0_22.png to (640, 640)
# Resized 6498dca8-173_0_135.png to (640, 640)
# Resized a95cb8e9-176_0_19.png to (640, 640)
# Resized 21211f56-176_1_48.png to (640, 640)
# Resized f9a01028-172_0_0.png to (640, 640)
# Resized 6334548d-172_0_0.png to (640, 640)
# Resized 4577450b-173_0_147.png to (640, 640)
# Resized 79961ac4-176_0_158.png to (640, 640)
# Resized 637e3cfb-172_0_114.png to (640, 640)
# Resized 2f0255df-172_0_132.png to (640, 640)
# Resized 1e66d5a5-173_0_2.png to (640, 640)
# Resized 07ed269a-172_0_25.png to (640, 640)
# Resized ffbbc096-176_0_165808.png to (640, 640)
# Resized 0ede1db7-173_0_5.png to (640, 640)
# Resized 9b8a27f5-173_0_85.png to (640, 640)
# Resized cf8e7a27-172_0_6.png to (640, 640)
# Resized 324f7c58-172_0_69.png to (640, 640)
# Resized 82cf3fc4-172_0_68.png to (640, 640)
# Resized 4a05cef0-176_0_78648.png to (640, 640)
# Resized 77f392bb-173_0_36.png to (640, 640)
# Resized c41162c1-173_0_60.png to (640, 640)
# Resized 46c27d86-173_0_19.png to (640, 640)
# Resized e81ba70a-176_0_511706.png to (640, 640)
# Resized 72bcb8da-172_0_103.png to (640, 640)
# Resized 7d65e082-173_0_0.png to (640, 640)
# Resized 438749e0-172_0_100.png to (640, 640)
# Resized 6f465cdd-176_0_134.png to (640, 640)
# Resized ffd8fb84-173_0_162.png to (640, 640)
# Resized 400f55c8-172_0_134.png to (640, 640)
# Resized 5e5f213d-173_0_63.png to (640, 640)
# Resized 4fa64e38-173_1_109.png to (640, 640)
# Resized 115b4940-173_1_107.png to (640, 640)
# Resized 03e0431a-176_1_15.png to (640, 640)
# Resized d6efb169-173_0_22.png to (640, 640)
# Resized 31c368d5-176_0_131.png to (640, 640)
# Resized 9e940ed4-173_1_122.png to (640, 640)
# Resized 2ecef013-172_1_132.png to (640, 640)
# Resized 422607b1-173_1_170.png to (640, 640)
# Resized 27053f03-172_0_129.png to (640, 640)
# Resized 093e0649-176_0_81.png to (640, 640)
# Resized 23a94c64-176_0_39.png to (640, 640)
# Resized b3fdadaf-172_1_110.png to (640, 640)
# Resized 7bac873a-173_0_18817.png to (640, 640)
# Resized 8a9c50ea-173_0_270183.png to (640, 640)
# Resized 0a3df008-173_0_115.png to (640, 640)
# Resized af3c183e-173_0_126.png to (640, 640)
# Resized 4de0090f-176_1_4.png to (640, 640)
# Resized 85e4fd83-173_0_38.png to (640, 640)
# Resized cd9f12ff-173_0_109.png to (640, 640)
# Resized 7413b065-172_0_81.png to (640, 640)
# Resized 2521b1a6-173_0_35.png to (640, 640)
# Resized cbddd7a9-173_0_55.png to (640, 640)
# Resized 0834c194-173_0_124.png to (640, 640)
# Resized 3f71fa45-176_1_78.png to (640, 640)
# Resized 0a8c09f2-172_0_94.png to (640, 640)
# Resized 51138405-172_0_124.png to (640, 640)
# Resized 2680bbce-172_0_40.png to (640, 640)
# Resized 26604d7c-173_1_150.png to (640, 640)
# Resized 01573fa1-173_0_87.png to (640, 640)
# Resized bd71e2b9-172_0_153.png to (640, 640)
# Resized 2138e652-172_0_50.png to (640, 640)
# Resized df8bc872-173_1_161.png to (640, 640)
# Resized 6e162c54-176_0_60.png to (640, 640)
# Resized 858232bc-176_0_58.png to (640, 640)
# Resized dafd737c-172_0_84.png to (640, 640)
# Resized 28d53e70-176_0_78.png to (640, 640)
# Resized d47ae581-172_0_34.png to (640, 640)
# Resized e7e9191f-173_0_11.png to (640, 640)
# Resized 9d6438be-173_0_0.png to (640, 640)
# Resized 71c77876-176_1_29.png to (640, 640)
# Resized 1de91a6d-172_0_106.png to (640, 640)
# Resized d4b3a764-173_0_77.png to (640, 640)
# Resized 62ad1ade-172_0_84.png to (640, 640)
# Resized 4bc88b01-173_0_204255.png to (640, 640)
# Resized bb7ffb18-172_0_16.png to (640, 640)
# Resized 36303f85-173_1_133.png to (640, 640)
# Resized 766c84cf-172_0_28.png to (640, 640)
# Resized 7ce5f108-172_0_19.png to (640, 640)
# Resized 2f248033-172_0_109.png to (640, 640)
# Resized 6b8b7148-173_1_111.png to (640, 640)
# Resized 6a9a740c-176_1_12.png to (640, 640)
# Resized 372bcbd3-172_0_22.png to (640, 640)
# Resized e69f7f20-173_0_147.png to (640, 640)
# Resized ce0b7eeb-172_0_110.png to (640, 640)
# Resized 143e4ffa-173_1_175.png to (640, 640)
# Resized 49b4abc8-173_0_177.png to (640, 640)
# Resized e7adb19b-173_0_639398.png to (640, 640)
# Resized 9c195ecd-173_0_44.png to (640, 640)
# Resized 00d25d77-176_0_0.png to (640, 640)
# Resized 3aaeba0e-173_0_91.png to (640, 640)
# Resized c6b2095d-172_1_153.png to (640, 640)
# Resized ea959557-173_0_134.png to (640, 640)
# Resized 532342ad-173_0_99.png to (640, 640)
# Resized 91cdd24a-173_0_158.png to (640, 640)
# Resized 1cbda433-172_0_49.png to (640, 640)
# Resized c01a9d44-176_1_106.png to (640, 640)
# Resized e00507bf-172_1_167.png to (640, 640)
# Resized c5074dea-176_0_10.png to (640, 640)
# Resized e734fa8d-176_1_94.png to (640, 640)
# Resized 0b9b124b-172_0_31.png to (640, 640)
# Resized 158a76c6-172_0_819059.png to (640, 640)
# Resized b283c5f6-176_1_24.png to (640, 640)
# Resized 01a37e80-172_0_116.png to (640, 640)
# Resized 77f65066-173_0_74.png to (640, 640)
# Resized 95a5bcea-176_0_102.png to (640, 640)
# Resized f87c8a33-176_0_126.png to (640, 640)
# Resized 4ab60f94-172_0_83.png to (640, 640)
# Resized 59b6ab75-176_1_51.png to (640, 640)
# Resized 95c20ffd-176_0_63.png to (640, 640)
# Resized 8b5c2983-173_0_126.png to (640, 640)
# Resized e7c75e67-173_0_100.png to (640, 640)
# Resized 4938cdfb-173_0_47.png to (640, 640)
# Resized d36ac669-173_0_164.png to (640, 640)
# Resized aa826c85-176_0_49.png to (640, 640)
# Resized 8bcce36f-173_0_145.png to (640, 640)
# Resized 38b0b6f0-172_0_150.png to (640, 640)
# Resized 0a55b5fa-176_0_16.png to (640, 640)
# Resized fe85cb8a-172_0_63.png to (640, 640)
# Resized 886d15f4-176_1_97.png to (640, 640)
# Resized 7b8f6abb-173_0_109.png to (640, 640)
# Resized 9807526a-172_0_1.png to (640, 640)
# Resized 9f8351b5-172_0_66.png to (640, 640)
# Resized 0ae70049-172_0_59.png to (640, 640)
# Resized e62c1503-172_1_162.png to (640, 640)
# Resized f31a224d-172_0_57.png to (640, 640)
# Resized fa59f285-172_0_10.png to (640, 640)
# Resized b922c26f-173_0_52.png to (640, 640)
# Resized 054fd16b-176_1_68.png to (640, 640)
# Resized b6fa1278-176_0_152.png to (640, 640)
# Resized 1150ef52-173_0_9.png to (640, 640)
# Resized a48d5915-173_1_127.png to (640, 640)
# Resized eb041ef2-173_0_107.png to (640, 640)
# Resized 8eee8ed5-172_1_138.png to (640, 640)
# Resized 73fc3a6c-173_0_122.png to (640, 640)
# Resized 45a4ad88-172_0_143.png to (640, 640)
# Resized c7f83cf1-172_0_79.png to (640, 640)
# Resized 6d9cca00-173_0_104.png to (640, 640)
# Resized 523ebd35-176_0_113.png to (640, 640)
# Resized 4db01d65-172_0_87.png to (640, 640)
# Resized a159b4ba-173_0_112.png to (640, 640)
# Resized bd63b4a7-172_0_3.png to (640, 640)
# Resized 88ef74a0-172_0_123.png to (640, 640)
# Resized 054adc69-173_0_115.png to (640, 640)
# Resized 4d1ff6d0-173_0_296228.png to (640, 640)
# Resized 08db368a-172_1_150.png to (640, 640)
# Resized 7d77cab6-173_0_69.png to (640, 640)
# Resized 4c2490b7-173_0_63.png to (640, 640)
# Resized e5b28764-173_0_16.png to (640, 640)
# Resized a07e9eff-172_0_65.png to (640, 640)
# Resized 681e677d-172_0_128.png to (640, 640)
# Resized 13d2044f-176_1_40.png to (640, 640)
# Resized 20df3720-172_0_102.png to (640, 640)
# Resized e3994350-173_0_163.png to (640, 640)
# Resized 978cd048-173_0_6.png to (640, 640)
# Resized 496e9c76-172_0_67372.png to (640, 640)
# Resized 8703e2e5-173_0_107.png to (640, 640)
# Resized bbbefe02-172_1_141.png to (640, 640)
# Resized 6cc7cbb7-172_0_43.png to (640, 640)
# Resized 232641cb-173_0_111.png to (640, 640)
# Resized 38ff1629-172_0_77.png to (640, 640)
# Resized adc5b70e-172_0_126.png to (640, 640)
# Resized 73424716-172_0_99.png to (640, 640)
# Resized 1f8d125d-173_0_99.png to (640, 640)
# Resized eb3e219b-173_0_167.png to (640, 640)
# Resized d060a208-176_0_69.png to (640, 640)
# Resized 2954efb2-173_1_115.png to (640, 640)
# Resized 081a8953-176_1_71.png to (640, 640)
# Resized 1d25588d-176_0_1.png to (640, 640)
# Resized 4b0017b5-173_0_15.png to (640, 640)
# Resized 5d81f9ad-176_1_108.png to (640, 640)
# Resized 3c7a3085-176_0_93.png to (640, 640)
# Resized a2359964-173_0_25.png to (640, 640)
# Resized 0e0ce147-172_1_129.png to (640, 640)
# Resized f0bad52a-173_1_125.png to (640, 640)
# Resized f51ecb62-172_0_71.png to (640, 640)
# Resized 0aa72bbb-173_1_104.png to (640, 640)
# Resized 39e7c2a7-176_0_45.png to (640, 640)
# Resized 210b94f5-176_0_13.png to (640, 640)
# Resized e8617e48-172_0_75.png to (640, 640)
# Resized 502b47cc-173_0_0.png to (640, 640)
# Resized df217d60-173_1_105.png to (640, 640)
# Resized c8cd7af9-176_0_84.png to (640, 640)
# Resized 755b5286-176_1_46.png to (640, 640)
# Resized 125caa17-176_0_122.png to (640, 640)
# Resized 84508161-172_0_104.png to (640, 640)
# Resized 0276fabb-172_0_5.png to (640, 640)
# Resized 2344b199-172_0_63.png to (640, 640)
# Resized b40fd862-172_0_46.png to (640, 640)
# Resized d89e2d52-173_0_136.png to (640, 640)
# Resized 7084807b-173_0_145.png to (640, 640)
# Resized 21942254-172_0_28.png to (640, 640)
# Resized e4a45780-173_0_71.png to (640, 640)
# Resized 08242fa1-172_0_8.png to (640, 640)
# Resized ea6c67cb-176_1_100.png to (640, 640)
# Resized 136d4804-173_0_117.png to (640, 640)
# Resized 84a0713c-176_0_140.png to (640, 640)
# Resized 418b35b5-172_0_37.png to (640, 640)
# Resized fce448ce-173_0_153.png to (640, 640)
# Resized 1c762c67-172_0_116.png to (640, 640)
# Resized eb3352f4-173_0_159.png to (640, 640)
# Resized 335a9dcf-176_1_89.png to (640, 640)
# Resized 810da742-176_0_104.png to (640, 640)
# Resized 3beaf126-176_0_7.png to (640, 640)
# Resized 11ddf669-172_0_31.png to (640, 640)
# Resized 5d7aaa3a-173_0_4.png to (640, 640)
# Resized f499e0e3-173_0_38.png to (640, 640)
# Resized 81b69441-172_0_14.png to (640, 640)
# Resized 9fc095cb-173_0_80.png to (640, 640)
# Resized fd20060d-173_0_131.png to (640, 640)
# Resized ed71659b-173_0_142.png to (640, 640)
# Resized c5676f1f-172_0_101.png to (640, 640)
# Resized f434e36e-173_0_101.png to (640, 640)
# Resized 0ee8be31-173_0_84.png to (640, 640)
# Resized 91045fa6-172_0_11.png to (640, 640)
# Resized a91986a8-172_0_52.png to (640, 640)
# Resized 11d1b527-176_0_96.png to (640, 640)
# Resized 1aa4dd7e-173_1_153.png to (640, 640)
# Resized 362b114f-172_0_78.png to (640, 640)
# Resized 0a778b91-173_0_135.png to (640, 640)
# Resized eb7e44c3-173_0_17.png to (640, 640)
# Resized 3fc392e9-173_0_123.png to (640, 640)
# Resized d258c2ef-172_0_161.png to (640, 640)
# Resized e479f98b-173_0_152.png to (640, 640)
# Resized 422f6318-172_0_138.png to (640, 640)
# Resized 3c7ee604-172_0_49.png to (640, 640)
# Resized c5f93884-172_0_144.png to (640, 640)
# Resized d0bc007c-173_0_132.png to (640, 640)

# %%
def resize_annotations(original_json_file, output_folder, target_size=(640, 640), original_shape=(8000, 6000)):
    
    # create annotations folder
    output_annotations_folder = os.path.join(output_folder, 'annotations')
    if not os.path.exists(output_annotations_folder):
        os.makedirs(output_annotations_folder)
    
    # Get shapes
    original_width, original_height = original_shape
    target_width, target_height = target_size

    # Compute scaling factors
    width_scale = target_width / original_width
    height_scale = target_height / original_height

    # Load JSON annotations
    with open(original_json_file, 'r') as f:
        annotations = json.load(f)

    # Update image dimensions
    for image_info in annotations['images']:
        image_info['width'] = target_width
        image_info['height'] = target_height

    # Resize images and update bounding box coordinates
    for annotation in annotations['annotations']:
        image_id = annotation['image_id']
        image_info = next(img for img in annotations['images'] if img['id'] == image_id)

        # Update bounding box coordinates by dividing by 10
        bbox = annotation['bbox']

        rescaled_bbox = [
            bbox[0] * width_scale,
            bbox[1] * height_scale,
            bbox[2] * width_scale,
            bbox[3] * height_scale
        ]

        # old
        # annotation['bbox'] = [coord / 10 for coord in bbox]
        annotation['bbox'] = rescaled_bbox

        # Update area by dividing by 100
        annotation['area'] /= width_scale * height_scale

    # Save updated JSON annotations
    full_json_file_path = os.path.join(output_annotations_folder, f'updated_annotation_{target_size[0]}_{target_size[1]}.json')
    with open(full_json_file_path, 'w') as f:
        json.dump(annotations, f, indent=2)

    return full_json_file_path

# %%
# Resize images and update annotations
output_json_path = resize_annotations(original_json_file, output_folder, target_size) # , input_folder, output_folder

# %% [markdown]
# # Coco Splitting

# %%
from pathlib import Path
from cocohelper import COCOHelper
from cocohelper.splitters.proportional import ProportionalDataSplitter

root_dir = Path(output_json_path)
image_dir = ""

# %%
root_dir
# Out:
# PosixPath('/Users/johannes/Code/labelstudio/NanoStore_Full_COCO_resized/annotations/updated_annotation_640_640.json')

# %%
print(f"Loading dataset: {output_json_path}")
ch = COCOHelper.load_json(output_json_path, img_dir=image_dir)
# Out:
# Loading dataset: /Users/johannes/Code/labelstudio/NanoStore_Full_COCO_resized/annotations/updated_annotation_640_640.json

# %%
splitter = ProportionalDataSplitter(70, 20, 10)
ch_train, ch_val, ch_test = splitter.apply(ch)
dest_dir = Path(os.path.join(output_folder, 'annotations'))

for ch, ch_name in zip([ch_train, ch_val, ch_test], ["train", "val", "test"]):
    print(f"Saving dataset: '{ch_name}'")
    fname = dest_dir / f"{ch_name}_640.json"
    ch.write_annotations_file(fname)
# Out:
# Saving dataset: 'train'
# Saving dataset: 'val'
# Saving dataset: 'test'
